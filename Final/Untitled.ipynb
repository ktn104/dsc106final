# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.basketball-reference.com/teams/LAL/stats_basic_totals.html"

# %%
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
soup.findAll('tr', limit=2)
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]

# %%
headers = headers[1:]
headers
# Out:
# ['Lg',
#  'Tm',
#  'W',
#  'L',
#  'Finish',
#  '\xa0',
#  'Age',
#  'Ht.',
#  'Wt.',
#  '\xa0',
#  'G',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]

# %%
stats = pd.DataFrame(player_stats, columns = headers)
stats.head(10)
# Out:
#     Lg   Tm   W   L Finish     Age  Ht.  Wt.    ...   FT%  ORB   DRB   TRB  \
# 0  NBA  LAL  17   3      1    29.5  6-7  225    ...  .747  198   699   897
# 1  NBA  LAL  37  45      4    26.2  6-7  219    ...  .699  835  2985  3820
# 2  NBA  LAL  35  47      3    23.7  6-7  216    ...  .714  876  2927  3803
# 3  NBA  LAL  26  56      4    25.1  6-7  216    ...  .754  933  2636  3569
# 4  NBA  LAL  17  65      5    26.5  6-7  219    ...  .781  878  2645  3523
# 5  NBA  LAL  21  61      5    27.0  6-7  218    ...  .741  952  2647  3599
# 6  NBA  LAL  27  55      5    26.8  6-7  214    ...  .757  745  2620  3365
# 7  NBA  LAL  45  37      3    30.7  6-6  216    ...  .692  942  2732  3674
# 8  NBA  LAL  41  25      1    29.7  6-7  226    ...  .756  799  2251  3050
# 9  NBA  LAL  57  25      1    30.2  6-7  220    ...  .779  989  2616  3605
#
#     AST  STL  BLK   TOV    PF   PTS
# 0   531  170  145   304   397  2244
# 1  2096  618  440  1284  1701  9165
# ...

# %%
df = pd.read_html('https://www.basketball-reference.com/teams/LAL/stats_basic_totals.html')

# %%
df = df[0]

# %%
df = pd.read_html('https://www.basketball-reference.com/leaders/pts_top_10.html')

# %%
df = df[0]

# %%
df["B"] = df["A"].str.extract("(\d*\.?\d+)", expand=True)
# Out:
#     Season   Lg                  1st                     2nd  \
# 0  2019-20  NBA      J. Harden (789)  G. Antetokounmpo (682)
# 1  2018-19  NBA     J. Harden (2818)        P. George (2159)
# 2  2017-18  NBA      L. James (2251)        J. Harden (2191)
# 3  2016-17  NBA  R. Westbrook (2558)        J. Harden (2356)
# 4  2015-16  NBA     J. Harden (2376)         S. Curry (2375)
#
#                 3rd                  4th                      5th  \
# 0   L. Dončić (636)       T. Young (603)           L. James (558)
# 1  K. Walker (2102)       B. Beal (2099)        D. Lillard (2067)
# 2   A. Davis (2110)  R. Westbrook (2028)  G. Antetokounmpo (2014)
# 3  I. Thomas (2199)      A. Davis (2099)          K. Towns (2061)
# 4  K. Durant (2029)      L. James (1920)        D. Lillard (1879)
#
#                    6th                      7th                8th  \
# 0       A. Davis (547)            B. Beal (546)  D. Mitchell (544)
# ...

# %%
year = df.head(39)

# %%
year
# Out:
#      Season   Lg                   1st                     2nd  \
# 0   2019-20  NBA       J. Harden (789)  G. Antetokounmpo (682)
# 1   2018-19  NBA      J. Harden (2818)        P. George (2159)
# 2   2017-18  NBA       L. James (2251)        J. Harden (2191)
# 3   2016-17  NBA   R. Westbrook (2558)        J. Harden (2356)
# 4   2015-16  NBA      J. Harden (2376)         S. Curry (2375)
# 5   2014-15  NBA      J. Harden (2217)         S. Curry (1900)
# 6   2013-14  NBA      K. Durant (2593)       C. Anthony (2112)
# 7   2012-13  NBA      K. Durant (2280)        K. Bryant (2133)
# 8   2011-12  NBA      K. Durant (1850)         L. James (1683)
# 9   2010-11  NBA      K. Durant (2161)         L. James (2111)
# 10  2009-10  NBA      K. Durant (2472)         L. James (2258)
# 11  2008-09  NBA        D. Wade (2386)         L. James (2304)
# 12  2007-08  NBA      K. Bryant (2323)         L. James (2250)
# 13  2006-07  NBA      K. Bryant (2430)         L. James (2132)
# ...
